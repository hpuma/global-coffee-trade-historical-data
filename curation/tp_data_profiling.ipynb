# %%
import pandas as pd

# %%
df = pd.read_excel("../data/total_production.xlsx", sheet_name=None)["Production"]
# Out:
# c:\Users\pumah\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# Column are incorrect and do not represent anything
df_columns = df.columns
print(df_columns)

print("Total:", len(df_columns))
# Out:
# Index(['Total production by all exporting countries', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31'],
#       dtype='object')
# Total: 32

# %%
# Df overview
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 32 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Total production by all exporting countries  62 non-null     object
#  1   Unnamed: 1                                   55 non-null     object
#  2   Unnamed: 2                                   60 non-null     object
#  3   Unnamed: 3                                   60 non-null     object
#  4   Unnamed: 4                                   60 non-null     object
#  5   Unnamed: 5                                   60 non-null     object
#  6   Unnamed: 6                                   60 non-null     object
#  7   Unnamed: 7                                   60 non-null     object
#  8   Unnamed: 8                                   60 non-null     object
# ...

# %%
# Notice how many NaNs are present in the "Total production by all exporting countries column"
display(df["Total production by all exporting countries"].unique)
# Out:
# <bound method Series.unique of 0                   In thousand 60kg bags
# 1                                     NaN
# 2                               Crop year
# 3                                     NaN
# 4                             April group
#                      ...
# 62                               Viet Nam
# 63                                  Yemen
# 64                                    NaN
# 65                                  Total
# 66    © International Coffee Organization
# Name: Total production by all exporting countries, Length: 67, dtype: object>

# %%
print("Total Number of rows:", df.size)
# Out:
# Total Number of rows: 2144

# %%
df
# Out:
#    Total production by all exporting countries Unnamed: 1  Unnamed: 2  \
# 0                        In thousand 60kg bags        NaN         NaN
# 1                                          NaN        NaN         NaN
# 2                                    Crop year        NaN     1990/91
# 3                                          NaN        NaN         NaN
# 4                                  April group        NaN  40795.2926
# ..                                         ...        ...         ...
# 62                                    Viet Nam      (R/A)    1310.288
# 63                                       Yemen        (A)           0
# 64                                         NaN        NaN         NaN
# 65                                       Total        NaN  93230.0596
# 66         © International Coffee Organization        NaN         NaN
#
#      Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7   Unnamed: 8  \
# ...

# %%
# Number of null or NaN in each column
df.isna().sum()
# Out:
# Total production by all exporting countries     5
# Unnamed: 1                                     12
# Unnamed: 2                                      7
# Unnamed: 3                                      7
# Unnamed: 4                                      7
# Unnamed: 5                                      7
# Unnamed: 6                                      7
# Unnamed: 7                                      7
# Unnamed: 8                                      7
# Unnamed: 9                                      7
# Unnamed: 10                                     7
# Unnamed: 11                                     7
# Unnamed: 12                                     7
# Unnamed: 13                                     7
# Unnamed: 14                                     7
# Unnamed: 15                                     7
# Unnamed: 16                                     7
# Unnamed: 17                                     7
# Unnamed: 18                                     7
# ...

# %%
# FIN
