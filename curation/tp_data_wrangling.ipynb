# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("../data/total_production.xlsx", sheet_name=None)
df = df["Production"]
df = df.rename({"Total production by all exporting countries": "Country"}, axis=1)
# We can also remove the second column `Unnamed: 1` as it provides no relevant information  
df = df.drop(columns="Unnamed: 1")
# Out:
# c:\Users\pumah\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# We can also remove the second column `Unnamed: 1` as it provides no relevant information
# Looking below, we can see that we have to remove the first 4 rows because row #3 contains the crop year along with the appropriate column names 
display(df.head())
# Out:
#                  Country  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0  In thousand 60kg bags         NaN         NaN         NaN         NaN
# 1                    NaN         NaN         NaN         NaN         NaN
# 2              Crop year     1990/91     1991/92     1992/93     1993/94
# 3                    NaN         NaN         NaN         NaN         NaN
# 4            April group  40795.2926  42529.5454  46868.2042  40166.7591
#
#    Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9 Unnamed: 10  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1         NaN         NaN         NaN         NaN         NaN  ...
# 2     1994/95     1995/96     1996/97     1997/98     1998/99  ...
# 3         NaN         NaN         NaN         NaN         NaN  ...
# 4  39990.3663  29395.9601  44297.8201  39475.8391  50892.4914  ...
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# ...

# %%
year_columns = df.columns[1:] # Get the current columns, except the first one (Country)
year_row = df.iloc[2][1:] # Get the new column names on row 3 which will be from 1900/91 and beyond

new_columns = dict(zip(year_columns, year_row)) # Create dictionary for mapping current column names to new column names
df = df.rename(columns = new_columns)
display(df)
# Out:
#                                 Country     1990/91      1991/92     1992/93  \
# 0                 In thousand 60kg bags         NaN          NaN         NaN
# 1                                   NaN         NaN          NaN         NaN
# 2                             Crop year     1990/91      1991/92     1992/93
# 3                                   NaN         NaN          NaN         NaN
# 4                           April group  40795.2926   42529.5454  46868.2042
# ..                                  ...         ...          ...         ...
# 62                             Viet Nam    1310.288     1437.848    2340.447
# 63                                Yemen           0            0           0
# 64                                  NaN         NaN          NaN         NaN
# 65                                Total  93230.0596  101266.6844  98524.0942
# 66  © International Coffee Organization         NaN          NaN         NaN
#
# ...

# %%
# Remove first 4 rows that are no longer necessary
df = df.iloc[4:]
display(df)
# Out:
# After removing the first 4 rows, we have the following rows:
#                                 Country     1990/91      1991/92     1992/93  \
# 4                           April group  40795.2926   42529.5454  46868.2042
# 5                                Angola      50.345       79.331       77.52
# 6      Bolivia (Plurinational State of)     122.777      103.536     120.235
# 7                                Brazil  27285.6286   27293.4934  34603.3542
# 8                               Burundi     487.393      667.199     620.238
# ..                                  ...         ...          ...         ...
# 62                             Viet Nam    1310.288     1437.848    2340.447
# 63                                Yemen           0            0           0
# 64                                  NaN         NaN          NaN         NaN
# 65                                Total  93230.0596  101266.6844  98524.0942
# ...

# %%
# # Remove comma from string values and turn into integers
# df[year_columns]  =  df[year_columns].apply(lambda x: x.str.replace(",", "")).astype(int)

# %%
# # Distinct Countries
# countries = df["Crop year"].unique()
# print("Distinct countries represented {}".format(countries))

# %%
# # Distinct Years
# years = df.columns.unique()
# print("Distinct years {}".format(years[2:]))

# %%
# print("Data frame has null values: {}".format(df.isnull().values.any()))

# %%
#
